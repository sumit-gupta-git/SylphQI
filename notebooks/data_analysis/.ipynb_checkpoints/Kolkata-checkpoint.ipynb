# %%
#importing dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
#reading data from city_day.csv taken from kaggle from 01-01-2015 to 31-12-2024 of various Indian Cities
df = pd.read_csv("India_Cities_AQI_Weather_2015_2024_Combined.csv")

# %%
df.head()
# Out:
#          Date   City  State  AQI AQI_Category  PM2.5  PM10  NO2  SO2    CO  \
# 0  2015-01-01  Delhi  Delhi  282         Poor    121   180   86   63  5.75
# 1  2015-01-02  Delhi  Delhi  210         Poor     85   139   59   45  4.10
# 2  2015-01-03  Delhi  Delhi  257         Poor    107   168   72   59  5.54
# 3  2015-01-04  Delhi  Delhi  193     Moderate     88   126   48   36  3.58
# 4  2015-01-05  Delhi  Delhi  274         Poor    124   145   83   53  4.85
#
#    ...  Min_Temperature_C  Avg_Temperature_C  Humidity_Percent  Rainfall_mm  \
# 0  ...               -6.0               -1.5              76.4          0.0
# 1  ...               -8.8               -3.1              48.9          0.0
# 2  ...               -4.5               -0.3              53.7          0.0
# 3  ...               -7.3               -0.6              76.7          0.0
# 4  ...               -3.1                4.4              66.1          0.0
#
#    Wind_Speed_kmh  Wind_Direction  Atmospheric_Pressure_hPa  Visibility_km  \
# 0            11.1               N                   1010.55           14.9
# 1             9.2               S                   1015.14           14.5
# 2             7.1              NE                   1017.66           14.2
# 3            10.4              NW                   1009.99           15.0
# 4            12.8              NE                   1016.24           15.0
#
#   Month  Season
# 0     1  Winter
# 1     1  Winter
# 2     1  Winter
# 3     1  Winter
# 4     1  Winter
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Analysing data

# %% [markdown]
# #### Understanding the Data and handling missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18265 entries, 0 to 18264
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      18265 non-null  object
#  1   City                      18265 non-null  object
#  2   State                     18265 non-null  object
#  3   AQI                       18265 non-null  int64
#  4   AQI_Category              18265 non-null  object
#  5   PM2.5                     18265 non-null  int64
#  6   PM10                      18265 non-null  int64
#  7   NO2                       18265 non-null  int64
#  8   SO2                       18265 non-null  int64
#  9   CO                        18265 non-null  float64
#  10  O3                        18265 non-null  int64
#  11  NH3                       18265 non-null  int64
#  12  Max_Temperature_C         18265 non-null  float64
#  13  Min_Temperature_C         18265 non-null  float64
#  14  Avg_Temperature_C         18265 non-null  float64
#  15  Humidity_Percent          18265 non-null  float64
#  16  Rainfall_mm               18265 non-null  float64
#  17  Wind_Speed_kmh            18265 non-null  float64
#  18  Wind_Direction            18265 non-null  object
#  19  Atmospheric_Pressure_hPa  18265 non-null  float64
#  20  Visibility_km             18265 non-null  float64
#  21  Month                     18265 non-null  int64
#  22  Season                    18265 non-null  object
# dtypes: float64(9), int64(8), object(6)
# memory usage: 3.2+ MB

# %%
df.shape
# Out:
# (18265, 23)

# %%
df.columns
# Out:
# Index(['Date', 'City', 'State', 'AQI', 'AQI_Category', 'PM2.5', 'PM10', 'NO2',
#        'SO2', 'CO', 'O3', 'NH3', 'Max_Temperature_C', 'Min_Temperature_C',
#        'Avg_Temperature_C', 'Humidity_Percent', 'Rainfall_mm',
#        'Wind_Speed_kmh', 'Wind_Direction', 'Atmospheric_Pressure_hPa',
#        'Visibility_km', 'Month', 'Season'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 AQI         PM2.5          PM10           NO2           SO2  \
# count  18265.000000  18265.000000  18265.000000  18265.000000  18265.000000
# mean     117.620476     46.519244     70.035532     34.795292     22.990857
# std       50.482348     22.559589     33.684170     17.062194     11.242799
# min       21.000000      1.000000      1.000000      1.000000      1.000000
# 25%       81.000000     30.000000     46.000000     23.000000     15.000000
# 50%      107.000000     43.000000     65.000000     33.000000     21.000000
# 75%      143.000000     59.000000     89.000000     44.000000     29.000000
# max      371.000000    167.000000    242.000000    118.000000     77.000000
#
#                  CO            O3           NH3  Max_Temperature_C  \
# count  18265.000000  18265.000000  18265.000000       18265.000000
# mean       2.357313     40.670025     17.231371          25.974563
# std        1.126961     21.112863      9.518506           9.786889
# min        0.100000      1.000000      1.000000          -3.700000
# 25%        1.570000     26.000000     10.000000          18.800000
# 50%        2.200000     38.000000     16.000000          26.100000
# 75%        2.980000     53.000000     23.000000          33.500000
# max        8.960000    142.000000     65.000000          52.100000
#
#        Min_Temperature_C  Avg_Temperature_C  Humidity_Percent   Rainfall_mm  \
# count       18265.000000       18265.000000      18265.000000  18265.000000
# mean           14.468119          20.221276         76.384216      1.266685
# std             9.987360           9.836193         13.852881      5.116442
# min           -17.800000         -10.800000         30.000000      0.000000
# 25%             7.100000          13.000000         66.600000      0.000000
# 50%            14.700000          20.300000         76.700000      0.000000
# 75%            22.100000          27.800000         86.700000      0.000000
# max            43.100000          47.600000        100.000000    134.400000
#
#        Wind_Speed_kmh  Atmospheric_Pressure_hPa  Visibility_km         Month
# count    18265.000000              18265.000000   18265.000000  18265.000000
# mean         8.822502               1013.242090       9.774481      6.522310
# std          3.592870                 10.039602       2.746346      3.448967
# min          0.000000                962.360000       0.500000      1.000000
# 25%          6.300000               1006.500000       7.900000      4.000000
# 50%          8.800000               1013.210000       9.800000      7.000000
# 75%         11.200000               1020.090000      11.800000     10.000000
# max         23.200000               1055.000000      15.000000     12.000000

# %%
#converting date column into datetime object
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18265 entries, 0 to 18264
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      18265 non-null  datetime64[ns]
#  1   City                      18265 non-null  object
#  2   State                     18265 non-null  object
#  3   AQI                       18265 non-null  int64
#  4   AQI_Category              18265 non-null  object
#  5   PM2.5                     18265 non-null  int64
#  6   PM10                      18265 non-null  int64
#  7   NO2                       18265 non-null  int64
#  8   SO2                       18265 non-null  int64
#  9   CO                        18265 non-null  float64
#  10  O3                        18265 non-null  int64
#  11  NH3                       18265 non-null  int64
#  12  Max_Temperature_C         18265 non-null  float64
#  13  Min_Temperature_C         18265 non-null  float64
#  14  Avg_Temperature_C         18265 non-null  float64
#  15  Humidity_Percent          18265 non-null  float64
#  16  Rainfall_mm               18265 non-null  float64
#  17  Wind_Speed_kmh            18265 non-null  float64
#  18  Wind_Direction            18265 non-null  object
#  19  Atmospheric_Pressure_hPa  18265 non-null  float64
#  20  Visibility_km             18265 non-null  float64
#  21  Month                     18265 non-null  int64
#  22  Season                    18265 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(8), object(5)
# memory usage: 3.2+ MB

# %%
#diving group based on city names
group_df = df.groupby("City")

#making city wise dataframe
kolkata_df = group_df.get_group("Kolkata")

# %%
kolkata_df
# Out:
#             Date     City        State  AQI AQI_Category  PM2.5  PM10  NO2  \
# 7306  2015-01-01  Kolkata  West Bengal  179     Moderate     84   100   58
# 7307  2015-01-02  Kolkata  West Bengal  185     Moderate     80   126   46
# 7308  2015-01-03  Kolkata  West Bengal   44         Good     29    34    5
# 7309  2015-01-04  Kolkata  West Bengal  177     Moderate     75   124   52
# 7310  2015-01-05  Kolkata  West Bengal  180     Moderate     50   125   52
# ...          ...      ...          ...  ...          ...    ...   ...  ...
# 10954 2024-12-27  Kolkata  West Bengal  160     Moderate     67   112   54
# 10955 2024-12-28  Kolkata  West Bengal  188     Moderate     84    93   57
# 10956 2024-12-29  Kolkata  West Bengal  182     Moderate     84   109   69
# 10957 2024-12-30  Kolkata  West Bengal  183     Moderate     73   104   43
# 10958 2024-12-31  Kolkata  West Bengal  190     Moderate     66   126   50
#
#        SO2    CO  ...  Min_Temperature_C  Avg_Temperature_C  Humidity_Percent  \
# 7306    44  3.14  ...               -2.3                4.5              79.8
# 7307    36  2.72  ...                7.1               11.8              77.1
# 7308     6  1.34  ...               -0.1                7.0              95.1
# 7309    31  4.10  ...               10.1               14.1              74.0
# 7310    33  4.31  ...                6.9               12.0              51.7
# ...    ...   ...  ...                ...                ...               ...
# 10954   21  2.91  ...               -0.0                5.5              75.2
# 10955   29  3.26  ...                8.9               13.9              71.5
# 10956   29  3.42  ...                0.5                7.7              81.1
# 10957   35  2.11  ...               11.3               15.4              81.1
# 10958   42  2.96  ...                4.0                9.4              78.6
#
#        Rainfall_mm  Wind_Speed_kmh  Wind_Direction  Atmospheric_Pressure_hPa  \
# 7306          0.00             4.9              SE                   1027.65
# 7307          0.00             5.2               S                   1030.23
# 7308          0.00             7.6               S                   1016.81
# 7309          0.00             6.3               N                   1027.27
# 7310          4.92             3.8               W                   1025.36
# ...            ...             ...             ...                       ...
# 10954         0.00             3.7              SE                   1010.93
# 10955         0.00             3.1               S                   1016.90
# 10956         0.00             6.2               S                   1008.25
# 10957         0.00             8.4               W                   1001.87
# 10958         0.00             3.9              SW                   1011.22
#
#        Visibility_km Month  Season
# 7306            12.4     1  Winter
# 7307            11.5     1  Winter
# 7308            12.2     1  Winter
# 7309            13.0     1  Winter
# 7310            15.0     1  Winter
# ...              ...   ...     ...
# 10954           13.6    12  Winter
# 10955            9.8    12  Winter
# 10956           14.7    12  Winter
# 10957            7.5    12  Winter
# 10958           11.9    12  Winter
#
# [3653 rows x 23 columns]

# %%
#reseting indices
kolkata_df = kolkata_df.reset_index(drop=True)

# %%
kolkata_df
# Out:
#            Date     City        State  AQI AQI_Category  PM2.5  PM10  NO2  \
# 0    2015-01-01  Kolkata  West Bengal  179     Moderate     84   100   58
# 1    2015-01-02  Kolkata  West Bengal  185     Moderate     80   126   46
# 2    2015-01-03  Kolkata  West Bengal   44         Good     29    34    5
# 3    2015-01-04  Kolkata  West Bengal  177     Moderate     75   124   52
# 4    2015-01-05  Kolkata  West Bengal  180     Moderate     50   125   52
# ...         ...      ...          ...  ...          ...    ...   ...  ...
# 3648 2024-12-27  Kolkata  West Bengal  160     Moderate     67   112   54
# 3649 2024-12-28  Kolkata  West Bengal  188     Moderate     84    93   57
# 3650 2024-12-29  Kolkata  West Bengal  182     Moderate     84   109   69
# 3651 2024-12-30  Kolkata  West Bengal  183     Moderate     73   104   43
# 3652 2024-12-31  Kolkata  West Bengal  190     Moderate     66   126   50
#
#       SO2    CO  ...  Min_Temperature_C  Avg_Temperature_C  Humidity_Percent  \
# 0      44  3.14  ...               -2.3                4.5              79.8
# 1      36  2.72  ...                7.1               11.8              77.1
# 2       6  1.34  ...               -0.1                7.0              95.1
# 3      31  4.10  ...               10.1               14.1              74.0
# 4      33  4.31  ...                6.9               12.0              51.7
# ...   ...   ...  ...                ...                ...               ...
# 3648   21  2.91  ...               -0.0                5.5              75.2
# 3649   29  3.26  ...                8.9               13.9              71.5
# 3650   29  3.42  ...                0.5                7.7              81.1
# 3651   35  2.11  ...               11.3               15.4              81.1
# 3652   42  2.96  ...                4.0                9.4              78.6
#
#       Rainfall_mm  Wind_Speed_kmh  Wind_Direction  Atmospheric_Pressure_hPa  \
# 0            0.00             4.9              SE                   1027.65
# 1            0.00             5.2               S                   1030.23
# 2            0.00             7.6               S                   1016.81
# 3            0.00             6.3               N                   1027.27
# 4            4.92             3.8               W                   1025.36
# ...           ...             ...             ...                       ...
# 3648         0.00             3.7              SE                   1010.93
# 3649         0.00             3.1               S                   1016.90
# 3650         0.00             6.2               S                   1008.25
# 3651         0.00             8.4               W                   1001.87
# 3652         0.00             3.9              SW                   1011.22
#
#       Visibility_km Month  Season
# 0              12.4     1  Winter
# 1              11.5     1  Winter
# 2              12.2     1  Winter
# 3              13.0     1  Winter
# 4              15.0     1  Winter
# ...             ...   ...     ...
# 3648           13.6    12  Winter
# 3649            9.8    12  Winter
# 3650           14.7    12  Winter
# 3651            7.5    12  Winter
# 3652           11.9    12  Winter
#
# [3653 rows x 23 columns]

# %% [markdown]
# ### Forecasting using FB Prophet

# %%
kolkata_df
# Out:
#            Date     City        State  AQI AQI_Category  PM2.5  PM10  NO2  \
# 0    2015-01-01  Kolkata  West Bengal  179     Moderate     84   100   58
# 1    2015-01-02  Kolkata  West Bengal  185     Moderate     80   126   46
# 2    2015-01-03  Kolkata  West Bengal   44         Good     29    34    5
# 3    2015-01-04  Kolkata  West Bengal  177     Moderate     75   124   52
# 4    2015-01-05  Kolkata  West Bengal  180     Moderate     50   125   52
# ...         ...      ...          ...  ...          ...    ...   ...  ...
# 3648 2024-12-27  Kolkata  West Bengal  160     Moderate     67   112   54
# 3649 2024-12-28  Kolkata  West Bengal  188     Moderate     84    93   57
# 3650 2024-12-29  Kolkata  West Bengal  182     Moderate     84   109   69
# 3651 2024-12-30  Kolkata  West Bengal  183     Moderate     73   104   43
# 3652 2024-12-31  Kolkata  West Bengal  190     Moderate     66   126   50
#
#       SO2    CO  ...  Min_Temperature_C  Avg_Temperature_C  Humidity_Percent  \
# 0      44  3.14  ...               -2.3                4.5              79.8
# 1      36  2.72  ...                7.1               11.8              77.1
# 2       6  1.34  ...               -0.1                7.0              95.1
# 3      31  4.10  ...               10.1               14.1              74.0
# 4      33  4.31  ...                6.9               12.0              51.7
# ...   ...   ...  ...                ...                ...               ...
# 3648   21  2.91  ...               -0.0                5.5              75.2
# 3649   29  3.26  ...                8.9               13.9              71.5
# 3650   29  3.42  ...                0.5                7.7              81.1
# 3651   35  2.11  ...               11.3               15.4              81.1
# 3652   42  2.96  ...                4.0                9.4              78.6
#
#       Rainfall_mm  Wind_Speed_kmh  Wind_Direction  Atmospheric_Pressure_hPa  \
# 0            0.00             4.9              SE                   1027.65
# 1            0.00             5.2               S                   1030.23
# 2            0.00             7.6               S                   1016.81
# 3            0.00             6.3               N                   1027.27
# 4            4.92             3.8               W                   1025.36
# ...           ...             ...             ...                       ...
# 3648         0.00             3.7              SE                   1010.93
# 3649         0.00             3.1               S                   1016.90
# 3650         0.00             6.2               S                   1008.25
# 3651         0.00             8.4               W                   1001.87
# 3652         0.00             3.9              SW                   1011.22
#
#       Visibility_km Month  Season
# 0              12.4     1  Winter
# 1              11.5     1  Winter
# 2              12.2     1  Winter
# 3              13.0     1  Winter
# 4              15.0     1  Winter
# ...             ...   ...     ...
# 3648           13.6    12  Winter
# 3649            9.8    12  Winter
# 3650           14.7    12  Winter
# 3651            7.5    12  Winter
# 3652           11.9    12  Winter
#
# [3653 rows x 23 columns]

# %%
kolkata_df.columns
# Out:
# Index(['Date', 'City', 'State', 'AQI', 'AQI_Category', 'PM2.5', 'PM10', 'NO2',
#        'SO2', 'CO', 'O3', 'NH3', 'Max_Temperature_C', 'Min_Temperature_C',
#        'Avg_Temperature_C', 'Humidity_Percent', 'Rainfall_mm',
#        'Wind_Speed_kmh', 'Wind_Direction', 'Atmospheric_Pressure_hPa',
#        'Visibility_km', 'Month', 'Season'],
#       dtype='object')

# %%
kolkata_df.index
# Out:
# RangeIndex(start=0, stop=3653, step=1)

# %%
#splitting each pollutant
#pm2.5
kolkata_pm25 = pd.DataFrame(kolkata_df[["Date", "PM2.5"]])
kolkata_pm25.columns = ["ds", "y"]

#pm10
kolkata_pm10 = pd.DataFrame(kolkata_df[["Date", "PM10"]])
kolkata_pm10.columns = ["ds", "y"]

#NO2
kolkata_no2 = pd.DataFrame(kolkata_df[["Date", "NO2"]])
kolkata_no2.columns = ["ds", "y"]

#NH3
kolkata_nh3 = pd.DataFrame(kolkata_df[["Date", "NH3"]])
kolkata_nh3.columns = ["ds", "y"]

#CO
kolkata_co = pd.DataFrame(kolkata_df[["Date", "CO"]])
kolkata_co.columns = ["ds", "y"]

#SO2
kolkata_so2 = pd.DataFrame(kolkata_df[["Date", "SO2"]])
kolkata_so2.columns = ["ds", "y"]

#O3
kolkata_o3 = pd.DataFrame(kolkata_df[["Date", "O3"]])
kolkata_o3.columns = ["ds", "y"]

# %%
kolkata_pm25['ds']
# Out:
# 0      2015-01-01
# 1      2015-01-02
# 2      2015-01-03
# 3      2015-01-04
# 4      2015-01-05
#           ...
# 3648   2024-12-27
# 3649   2024-12-28
# 3650   2024-12-29
# 3651   2024-12-30
# 3652   2024-12-31
# Name: ds, Length: 3653, dtype: datetime64[ns]

# %%
from prophet import Prophet

# %%
#initialize prophet for each pollutant
model_pm25 = Prophet()
model_pm25.fit(kolkata_pm25)

#future timestamps
future_pm25 = model_pm25.make_future_dataframe(periods=365)

#predictions
forecast_pm25 = model_pm25.predict(future_pm25)

#print results
print(forecast_pm25[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 11:19:30 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:31 - cmdstanpy - INFO - Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  62.575994   45.985331   81.553776
# 4014 2025-12-28  63.220774   43.533223   81.428625
# 4015 2025-12-29  68.739670   50.265606   87.887963
# 4016 2025-12-30  69.356536   50.282458   87.620314
# 4017 2025-12-31  69.421524   51.893581   88.113140

# %%
model_pm10 = Prophet()
model_pm10.fit(kolkata_pm10)

#future timestamps
future_pm10 = model_pm10.make_future_dataframe(periods=365)

#predictions
forecast_pm10 = model_pm10.predict(future_pm10)

#print results
print(forecast_pm10[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 11:19:32 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:33 - cmdstanpy - INFO - Chain [1] done processing
#              ds        yhat  yhat_lower  yhat_upper
# 4013 2025-12-27   94.461816   65.490949  122.518502
# 4014 2025-12-28   95.440827   65.271113  123.054622
# 4015 2025-12-29  102.205468   72.744255  131.084902
# 4016 2025-12-30  103.587631   75.356990  132.296140
# 4017 2025-12-31  102.148109   72.899978  130.399069

# %%
#initialize prophet for each pollutant
model_no2 = Prophet()
model_no2.fit(kolkata_no2)

#future timestamps
future_no2 = model_no2.make_future_dataframe(periods=365)

#predictions
forecast_no2 = model_no2.predict(future_no2)

#print results
print(forecast_no2[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 11:19:34 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:34 - cmdstanpy - INFO - Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  46.453016   32.854103   60.849223
# 4014 2025-12-28  46.992718   32.018539   61.032520
# 4015 2025-12-29  50.338653   36.402337   64.273312
# 4016 2025-12-30  50.650629   35.911351   65.498010
# 4017 2025-12-31  50.596257   36.822645   63.895661

# %%
#initialize prophet for each pollutant
model_nh3 = Prophet()
model_nh3.fit(kolkata_nh3)

#future timestamps
future_nh3 = model_nh3.make_future_dataframe(periods=365)

#predictions
forecast_nh3 = model_nh3.predict(future_nh3)

#print results
print(forecast_nh3[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 11:19:35 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:35 - cmdstanpy - INFO - Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  22.480263   13.009665   31.807687
# 4014 2025-12-28  22.974102   13.961397   31.998464
# 4015 2025-12-29  25.602543   16.095373   34.501781
# 4016 2025-12-30  26.058267   16.718986   34.823767
# 4017 2025-12-31  25.337538   16.040815   34.154336

# %%
#initialize prophet for each pollutant
model_co = Prophet()
model_co.fit(kolkata_co)

#future timestamps
future_co = model_co.make_future_dataframe(periods=365)

#predictions
forecast_co = model_co.predict(future_co)

#print results
print(forecast_co[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 11:19:36 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:37 - cmdstanpy - INFO - Chain [1] done processing
#              ds      yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  3.122724    2.178559    4.083321
# 4014 2025-12-28  3.097581    2.136010    4.091906
# 4015 2025-12-29  3.383966    2.445286    4.334296
# 4016 2025-12-30  3.427472    2.413640    4.309256
# 4017 2025-12-31  3.409460    2.506193    4.380211

# %%
#initialize prophet for each pollutant
model_so2 = Prophet()
model_so2.fit(kolkata_so2)

#future timestamps
future_so2 = model_so2.make_future_dataframe(periods=365)

#predictions
forecast_so2 = model_so2.predict(future_so2)

#print results
print(forecast_so2[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 11:19:38 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:38 - cmdstanpy - INFO - Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  30.250217   21.314551   39.395867
# 4014 2025-12-28  30.461380   20.502014   39.541030
# 4015 2025-12-29  33.246098   23.925524   42.540293
# 4016 2025-12-30  33.172366   23.758486   42.822451
# 4017 2025-12-31  33.087603   23.747229   41.875303

# %%
#initialize prophet for each pollutant
model_o3 = Prophet()
model_o3.fit(kolkata_o3)

#future timestamps
future_o3 = model_o3.make_future_dataframe(periods=365)

#predictions
forecast_o3 = model_o3.predict(future_o3)

#print results
print(forecast_o3[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 11:19:39 - cmdstanpy - INFO - Chain [1] start processing
# 11:19:39 - cmdstanpy - INFO - Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  51.311417   31.498404   69.178920
# 4014 2025-12-28  52.389001   32.313394   72.109306
# 4015 2025-12-29  58.019505   38.515983   77.139823
# 4016 2025-12-30  56.392727   36.629310   76.183210
# 4017 2025-12-31  57.796854   39.019756   76.430589

# %% [markdown]
# ### Plotting the forecast and trend

# %%
model_pm25.plot(forecast_pm25)
plt.title('PM2.5 Forcasted')
plt.show()

# %%
model_pm25.plot_components(forecast_pm25)
plt.suptitle('PM2.5 Forecast Components')
plt.show()

# %%
kolkata_pm25.describe()
# Out:
#                         ds            y
# count                 3653  3653.000000
# mean   2020-01-01 00:00:00    51.411169
# min    2015-01-01 00:00:00     1.000000
# 25%    2017-07-02 00:00:00    39.000000
# 50%    2020-01-01 00:00:00    50.000000
# 75%    2022-07-02 00:00:00    63.000000
# max    2024-12-31 00:00:00   135.000000
# std                    NaN    18.066980

# %%
forecast_pm25['yhat'].describe()
# Out:
# count    4018.000000
# mean       51.534766
# std        10.664662
# min        31.814335
# 25%        42.541122
# 50%        50.407081
# 75%        61.467246
# max        72.282903
# Name: yhat, dtype: float64

# %% [markdown]
# ## Observation

# %% [markdown]
# Concentration of PM2.5 have a down trend till 2018 then it starts increasing, it is maximum on weekdays throughout the year, and it is minimum during monsoon(July-Sept)

# %% [markdown]
# Similar pattern can be seen with other pollutants.

# %% [markdown]
# ## Correlation between Weather and AQI

# %%
kolkata_df.columns
# Out:
# Index(['Date', 'City', 'State', 'AQI', 'AQI_Category', 'PM2.5', 'PM10', 'NO2',
#        'SO2', 'CO', 'O3', 'NH3', 'Max_Temperature_C', 'Min_Temperature_C',
#        'Avg_Temperature_C', 'Humidity_Percent', 'Rainfall_mm',
#        'Wind_Speed_kmh', 'Wind_Direction', 'Atmospheric_Pressure_hPa',
#        'Visibility_km', 'Month', 'Season'],
#       dtype='object')

# %%
kolkata_df[['AQI','Max_Temperature_C', 'Min_Temperature_C', 'Avg_Temperature_C', 'Humidity_Percent', 'Rainfall_mm', 'Wind_Speed_kmh', 'Atmospheric_Pressure_hPa', 'Visibility_km']].corr()
# Out:
#                                AQI  Max_Temperature_C  Min_Temperature_C  \
# AQI                       1.000000          -0.549606          -0.532435
# Max_Temperature_C        -0.549606           1.000000           0.973553
# Min_Temperature_C        -0.532435           0.973553           1.000000
# Avg_Temperature_C        -0.544475           0.993161           0.993552
# Humidity_Percent         -0.311862           0.321996           0.312815
# Rainfall_mm              -0.129136           0.173725           0.173695
# Wind_Speed_kmh           -0.004433           0.015996           0.016240
# Atmospheric_Pressure_hPa  0.003381           0.007364           0.002014
# Visibility_km             0.351190          -0.648034          -0.632419
#
#                           Avg_Temperature_C  Humidity_Percent  Rainfall_mm  \
# AQI                               -0.544475         -0.311862    -0.129136
# Max_Temperature_C                  0.993161          0.321996     0.173725
# Min_Temperature_C                  0.993552          0.312815     0.173695
# Avg_Temperature_C                  1.000000          0.319414     0.174968
# Humidity_Percent                   0.319414          1.000000     0.141123
# Rainfall_mm                        0.174968          0.141123     1.000000
# Wind_Speed_kmh                     0.016212          0.015682     0.027057
# Atmospheric_Pressure_hPa           0.004663          0.000034    -0.007568
# Visibility_km                     -0.644438         -0.190659    -0.088852
#
#                           Wind_Speed_kmh  Atmospheric_Pressure_hPa  \
# AQI                            -0.004433                  0.003381
# Max_Temperature_C               0.015996                  0.007364
# Min_Temperature_C               0.016240                  0.002014
# Avg_Temperature_C               0.016212                  0.004663
# Humidity_Percent                0.015682                  0.000034
# Rainfall_mm                     0.027057                 -0.007568
# Wind_Speed_kmh                  1.000000                 -0.003898
# Atmospheric_Pressure_hPa       -0.003898                  1.000000
# Visibility_km                  -0.008307                 -0.013566
#
#                           Visibility_km
# AQI                            0.351190
# Max_Temperature_C             -0.648034
# Min_Temperature_C             -0.632419
# Avg_Temperature_C             -0.644438
# Humidity_Percent              -0.190659
# Rainfall_mm                   -0.088852
# Wind_Speed_kmh                -0.008307
# Atmospheric_Pressure_hPa      -0.013566
# Visibility_km                  1.000000

# %%
#visualising with heatmap
sns.heatmap(kolkata_df[['AQI','Max_Temperature_C', 'Min_Temperature_C', 'Avg_Temperature_C', 'Humidity_Percent', 'Rainfall_mm', 'Wind_Speed_kmh', 'Atmospheric_Pressure_hPa', 'Visibility_km']].corr())
# Out:
# <Axes: >

# %% [markdown]
# ## Observation

# %% [markdown]
# AQI is highly affected by temparature, humidity and rainfall, but it is seen that it does not get much affected from wind speed and atmospheric pressure.

# %%
kolkata_df['AQI'].describe()
# Out:
# count    3653.000000
# mean      129.868327
# std        37.529432
# min        35.000000
# 25%       102.000000
# 50%       124.000000
# 75%       155.000000
# max       296.000000
# Name: AQI, dtype: float64

# %% [markdown]
# ## Conclusion

# %% [markdown]
# kolkata, being a Western city, experiences varied Air Quality throught the year due to various changes in concentration of pollutants due to seasonal and weather changes. In comparison to oter cities, it witness bad air quality less than that of Delhi but more than others throught the year.
