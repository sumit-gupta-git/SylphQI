# %%
#importing dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
#reading data from city_day.csv taken from kaggle from 01-01-2015 to 31-12-2024 of various Indian Cities
df = pd.read_csv("India_Cities_AQI_Weather_2015_2024_Combined.csv")

# %%
df.head()
# Out:
#          Date   City  State  AQI AQI_Category  PM2.5  PM10  NO2  SO2    CO  \
# 0  2015-01-01  Delhi  Delhi  282         Poor    121   180   86   63  5.75
# 1  2015-01-02  Delhi  Delhi  210         Poor     85   139   59   45  4.10
# 2  2015-01-03  Delhi  Delhi  257         Poor    107   168   72   59  5.54
# 3  2015-01-04  Delhi  Delhi  193     Moderate     88   126   48   36  3.58
# 4  2015-01-05  Delhi  Delhi  274         Poor    124   145   83   53  4.85
#
#    ...  Min_Temperature_C  Avg_Temperature_C  Humidity_Percent  Rainfall_mm  \
# 0  ...               -6.0               -1.5              76.4          0.0
# 1  ...               -8.8               -3.1              48.9          0.0
# 2  ...               -4.5               -0.3              53.7          0.0
# 3  ...               -7.3               -0.6              76.7          0.0
# 4  ...               -3.1                4.4              66.1          0.0
#
#    Wind_Speed_kmh  Wind_Direction  Atmospheric_Pressure_hPa  Visibility_km  \
# 0            11.1               N                   1010.55           14.9
# 1             9.2               S                   1015.14           14.5
# 2             7.1              NE                   1017.66           14.2
# 3            10.4              NW                   1009.99           15.0
# 4            12.8              NE                   1016.24           15.0
#
#   Month  Season
# 0     1  Winter
# 1     1  Winter
# 2     1  Winter
# 3     1  Winter
# 4     1  Winter
#
# [5 rows x 23 columns]

# %%
#converting date column into datetime object
df["Date"]=pd.to_datetime(df["Date"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18265 entries, 0 to 18264
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      18265 non-null  datetime64[ns]
#  1   City                      18265 non-null  object
#  2   State                     18265 non-null  object
#  3   AQI                       18265 non-null  int64
#  4   AQI_Category              18265 non-null  object
#  5   PM2.5                     18265 non-null  int64
#  6   PM10                      18265 non-null  int64
#  7   NO2                       18265 non-null  int64
#  8   SO2                       18265 non-null  int64
#  9   CO                        18265 non-null  float64
#  10  O3                        18265 non-null  int64
#  11  NH3                       18265 non-null  int64
#  12  Max_Temperature_C         18265 non-null  float64
#  13  Min_Temperature_C         18265 non-null  float64
#  14  Avg_Temperature_C         18265 non-null  float64
#  15  Humidity_Percent          18265 non-null  float64
#  16  Rainfall_mm               18265 non-null  float64
#  17  Wind_Speed_kmh            18265 non-null  float64
#  18  Wind_Direction            18265 non-null  object
#  19  Atmospheric_Pressure_hPa  18265 non-null  float64
#  20  Visibility_km             18265 non-null  float64
#  21  Month                     18265 non-null  int64
#  22  Season                    18265 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(8), object(5)
# memory usage: 3.2+ MB

# %%
#diving group based on city names
group_df = df.groupby("City")

#making city wise dataframe
mumbai_df = group_df.get_group("Mumbai")

# %%
mumbai_df.head()
# Out:
#             Date    City        State  AQI  AQI_Category  PM2.5  PM10  NO2  \
# 10959 2015-01-01  Mumbai  Maharashtra  152      Moderate     71   108   44
# 10960 2015-01-02  Mumbai  Maharashtra  113      Moderate     37    73   32
# 10961 2015-01-03  Mumbai  Maharashtra   91  Satisfactory     38    60   20
# 10962 2015-01-04  Mumbai  Maharashtra  132      Moderate     39    70   42
# 10963 2015-01-05  Mumbai  Maharashtra  111      Moderate     49    65   23
#
#        SO2    CO  ...  Min_Temperature_C  Avg_Temperature_C  Humidity_Percent  \
# 10959   19  2.44  ...                6.0               12.6              91.1
# 10960   13  2.20  ...                0.8                7.3              75.2
# 10961   15  1.10  ...                5.2               12.5              80.8
# 10962   31  2.81  ...               11.6               16.0              96.3
# 10963   28  2.26  ...                6.4               13.0              81.2
#
#        Rainfall_mm  Wind_Speed_kmh  Wind_Direction  Atmospheric_Pressure_hPa  \
# 10959         0.00             9.3              SW                   1011.08
# 10960         0.00             7.9               E                   1006.90
# 10961         0.00             8.2               S                   1011.01
# 10962         0.00            12.4              SW                   1002.87
# 10963         5.16             8.3               S                   1005.17
#
#        Visibility_km Month  Season
# 10959           11.0     1  Winter
# 10960           11.4     1  Winter
# 10961           11.0     1  Winter
# 10962            9.0     1  Winter
# 10963           10.6     1  Winter
#
# [5 rows x 23 columns]

# %%
#reseting indices
mumbai_df = mumbai_df.reset_index(drop=True)

# %%
mumbai_df.head()
# Out:
#         Date    City        State  AQI  AQI_Category  PM2.5  PM10  NO2  SO2  \
# 0 2015-01-01  Mumbai  Maharashtra  152      Moderate     71   108   44   19
# 1 2015-01-02  Mumbai  Maharashtra  113      Moderate     37    73   32   13
# 2 2015-01-03  Mumbai  Maharashtra   91  Satisfactory     38    60   20   15
# 3 2015-01-04  Mumbai  Maharashtra  132      Moderate     39    70   42   31
# 4 2015-01-05  Mumbai  Maharashtra  111      Moderate     49    65   23   28
#
#      CO  ...  Min_Temperature_C  Avg_Temperature_C  Humidity_Percent  \
# 0  2.44  ...                6.0               12.6              91.1
# 1  2.20  ...                0.8                7.3              75.2
# 2  1.10  ...                5.2               12.5              80.8
# 3  2.81  ...               11.6               16.0              96.3
# 4  2.26  ...                6.4               13.0              81.2
#
#    Rainfall_mm  Wind_Speed_kmh  Wind_Direction  Atmospheric_Pressure_hPa  \
# 0         0.00             9.3              SW                   1011.08
# 1         0.00             7.9               E                   1006.90
# 2         0.00             8.2               S                   1011.01
# 3         0.00            12.4              SW                   1002.87
# 4         5.16             8.3               S                   1005.17
#
#    Visibility_km Month  Season
# 0           11.0     1  Winter
# 1           11.4     1  Winter
# 2           11.0     1  Winter
# 3            9.0     1  Winter
# 4           10.6     1  Winter
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Forecasting using FB Prophet

# %%
#splitting each pollutant
#pm2.5
mumbai_pm25 = pd.DataFrame(mumbai_df[["Date", "PM2.5"]])
mumbai_pm25.columns = ["ds", "y"]

#pm10
mumbai_pm10 = pd.DataFrame(mumbai_df[["Date", "PM10"]])
mumbai_pm10.columns = ["ds", "y"]

#NO2
mumbai_no2 = pd.DataFrame(mumbai_df[["Date", "NO2"]])
mumbai_no2.columns = ["ds", "y"]

#NH3
mumbai_nh3 = pd.DataFrame(mumbai_df[["Date", "NH3"]])
mumbai_nh3.columns = ["ds", "y"]

#CO
mumbai_co = pd.DataFrame(mumbai_df[["Date", "CO"]])
mumbai_co.columns = ["ds", "y"]

#SO2
mumbai_so2 = pd.DataFrame(mumbai_df[["Date", "SO2"]])
mumbai_so2.columns = ["ds", "y"]

#O3
mumbai_o3 = pd.DataFrame(mumbai_df[["Date", "O3"]])
mumbai_o3.columns = ["ds", "y"]

# %%
from prophet import Prophet

# %%
#initialize prophet for each pollutant
model_pm25 = Prophet()
model_pm25.fit(mumbai_pm25)

#future timestamps
future_pm25 = model_pm25.make_future_dataframe(periods=365)

#predictions
forecast_pm25 = model_pm25.predict(future_pm25)

#print results
print(forecast_pm25[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 12:09:30 - cmdstanpy - INFO - Chain [1] start processing
# 12:09:30 - cmdstanpy - INFO - Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  52.856034   35.790015   69.963071
# 4014 2025-12-28  53.629814   36.429804   71.274965
# 4015 2025-12-29  57.128561   40.281190   75.443482
# 4016 2025-12-30  58.898366   42.560317   75.260511
# 4017 2025-12-31  58.083182   41.011283   74.160406

# %%
model_pm10 = Prophet()
model_pm10.fit(mumbai_pm10)

#future timestamps
future_pm10 = model_pm10.make_future_dataframe(periods=365)

#predictions
forecast_pm10 = model_pm10.predict(future_pm10)

#print results
print(forecast_pm10[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 12:11:09 - cmdstanpy - INFO - Chain [1] start processing
# 12:11:10 - cmdstanpy - INFO - Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  79.301153   53.553664  104.601094
# 4014 2025-12-28  80.134730   56.396080  106.498125
# 4015 2025-12-29  83.813914   57.945968  108.903989
# 4016 2025-12-30  86.978358   59.218426  113.151281
# 4017 2025-12-31  86.268272   59.513109  112.640915

# %%
#initialize prophet for each pollutant
model_no2 = Prophet()
model_no2.fit(mumbai_no2)

#future timestamps
future_no2 = model_no2.make_future_dataframe(periods=365)

#predictions
forecast_no2 = model_no2.predict(future_no2)

#print results
print(forecast_no2[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 12:11:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:11:12 - cmdstanpy - INFO - Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  38.302653   24.857802   50.715415
# 4014 2025-12-28  39.981682   27.513681   53.923196
# 4015 2025-12-29  42.862602   29.414580   55.227193
# 4016 2025-12-30  43.621606   30.800931   56.093090
# 4017 2025-12-31  42.921492   29.714028   56.534896

# %%
#initialize prophet for each pollutant
model_nh3 = Prophet()
model_nh3.fit(mumbai_nh3)

#future timestamps
future_nh3 = model_nh3.make_future_dataframe(periods=365)

#predictions
forecast_nh3 = model_nh3.predict(future_nh3)

#print results
print(forecast_nh3[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 12:11:13 - cmdstanpy - INFO - Chain [1] start processing
# 12:11:14 - cmdstanpy - INFO - Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  19.236351   10.154178   27.803655
# 4014 2025-12-28  18.777636    9.954778   26.672840
# 4015 2025-12-29  20.659185   11.943559   29.894966
# 4016 2025-12-30  20.834884   11.451265   29.591923
# 4017 2025-12-31  20.560418   11.974974   29.176900

# %%
#initialize prophet for each pollutant
model_co = Prophet()
model_co.fit(mumbai_co)

#future timestamps
future_co = model_co.make_future_dataframe(periods=365)

#predictions
forecast_co = model_co.predict(future_co)

#print results
print(forecast_co[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 12:11:15 - cmdstanpy - INFO - Chain [1] start processing
# 12:11:15 - cmdstanpy - INFO - Chain [1] done processing
#              ds      yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  2.582171    1.744377    3.436766
# 4014 2025-12-28  2.587159    1.785796    3.407136
# 4015 2025-12-29  2.759474    1.933280    3.594744
# 4016 2025-12-30  2.788644    1.890944    3.640325
# 4017 2025-12-31  2.777048    1.934266    3.617969

# %%
#initialize prophet for each pollutant
model_so2 = Prophet()
model_so2.fit(mumbai_so2)

#future timestamps
future_so2 = model_so2.make_future_dataframe(periods=365)

#predictions
forecast_so2 = model_so2.predict(future_so2)

#print results
print(forecast_so2[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 12:11:17 - cmdstanpy - INFO - Chain [1] start processing
# 12:11:17 - cmdstanpy - INFO - Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  26.789730   18.089856   35.917071
# 4014 2025-12-28  27.145171   18.603496   35.337764
# 4015 2025-12-29  28.915498   20.161737   37.678960
# 4016 2025-12-30  29.629469   20.421662   38.156220
# 4017 2025-12-31  29.086365   20.639555   37.461286

# %%
#initialize prophet for each pollutant
model_o3 = Prophet()
model_o3.fit(mumbai_o3)

#future timestamps
future_o3 = model_o3.make_future_dataframe(periods=365)

#predictions
forecast_o3 = model_o3.predict(future_o3)

#print results
print(forecast_o3[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail())
# Out:
# 12:11:18 - cmdstanpy - INFO - Chain [1] start processing
# 12:11:19 - cmdstanpy - INFO - Chain [1] done processing
#              ds       yhat  yhat_lower  yhat_upper
# 4013 2025-12-27  44.812870   26.609755   62.758657
# 4014 2025-12-28  45.181119   27.063920   64.113234
# 4015 2025-12-29  48.648673   30.199285   67.440669
# 4016 2025-12-30  50.833832   33.065121   68.560379
# 4017 2025-12-31  50.966884   33.412994   68.617704

# %% [markdown]
# ## Plotting forecast and trend

# %%
model_pm25.plot(forecast_pm25)
plt.title('PM2.5 Forcasted')
plt.show()

# %%
model_pm25.plot_components(forecast_pm25)
plt.suptitle('PM2.5 Forecast Components')
plt.show()

# %%
mumbai_pm25.describe()
# Out:
#                         ds            y
# count                 3653  3653.000000
# mean   2020-01-01 00:00:00    43.120449
# min    2015-01-01 00:00:00     1.000000
# 25%    2017-07-02 00:00:00    31.000000
# 50%    2020-01-01 00:00:00    42.000000
# 75%    2022-07-02 00:00:00    54.000000
# max    2024-12-31 00:00:00   107.000000
# std                    NaN    16.231578

# %%
forecast_pm25['yhat'].describe()
# Out:
# count    4018.000000
# mean       43.146556
# std         9.030433
# min        27.316123
# 25%        35.168485
# 50%        41.933384
# 75%        51.817036
# max        58.898366
# Name: yhat, dtype: float64

# %% [markdown]
# ## Observation

# %% [markdown]
# Concentration of PM2.5 has been on increase since 2019, it peaks during weekdays and it is minumum during monsoon(July to Sept) but maximum during winters(Nov to Feb)

# %% [markdown]
# Similar patterns can be seen with other pollutants

# %% [markdown]
# ## Correlation between Weather and AQI

# %%
mumbai_df[['AQI','Max_Temperature_C', 'Min_Temperature_C', 'Avg_Temperature_C', 'Humidity_Percent', 'Rainfall_mm', 'Wind_Speed_kmh', 'Atmospheric_Pressure_hPa', 'Visibility_km']].corr()
# Out:
#                                AQI  Max_Temperature_C  Min_Temperature_C  \
# AQI                       1.000000          -0.516455          -0.491213
# Max_Temperature_C        -0.516455           1.000000           0.957909
# Min_Temperature_C        -0.491213           0.957909           1.000000
# Avg_Temperature_C        -0.508976           0.988903           0.989901
# Humidity_Percent         -0.331098           0.325265           0.304047
# Rainfall_mm              -0.150821           0.153075           0.145433
# Wind_Speed_kmh            0.039937          -0.029777          -0.031703
# Atmospheric_Pressure_hPa -0.014509           0.005241          -0.001402
# Visibility_km             0.278816          -0.555052          -0.522731
#
#                           Avg_Temperature_C  Humidity_Percent  Rainfall_mm  \
# AQI                               -0.508976         -0.331098    -0.150821
# Max_Temperature_C                  0.988903          0.325265     0.153075
# Min_Temperature_C                  0.989901          0.304047     0.145433
# Avg_Temperature_C                  1.000000          0.317726     0.150624
# Humidity_Percent                   0.317726          1.000000     0.145283
# Rainfall_mm                        0.150624          0.145283     1.000000
# Wind_Speed_kmh                    -0.031070         -0.019343     0.002652
# Atmospheric_Pressure_hPa           0.001954         -0.017673     0.007665
# Visibility_km                     -0.544259         -0.152163    -0.057022
#
#                           Wind_Speed_kmh  Atmospheric_Pressure_hPa  \
# AQI                             0.039937                 -0.014509
# Max_Temperature_C              -0.029777                  0.005241
# Min_Temperature_C              -0.031703                 -0.001402
# Avg_Temperature_C              -0.031070                  0.001954
# Humidity_Percent               -0.019343                 -0.017673
# Rainfall_mm                     0.002652                  0.007665
# Wind_Speed_kmh                  1.000000                  0.008323
# Atmospheric_Pressure_hPa        0.008323                  1.000000
# Visibility_km                   0.026215                 -0.018464
#
#                           Visibility_km
# AQI                            0.278816
# Max_Temperature_C             -0.555052
# Min_Temperature_C             -0.522731
# Avg_Temperature_C             -0.544259
# Humidity_Percent              -0.152163
# Rainfall_mm                   -0.057022
# Wind_Speed_kmh                 0.026215
# Atmospheric_Pressure_hPa      -0.018464
# Visibility_km                  1.000000

# %%
#visualising with heatmap
sns.heatmap(mumbai_df[['AQI','Max_Temperature_C', 'Min_Temperature_C', 'Avg_Temperature_C', 'Humidity_Percent', 'Rainfall_mm', 'Wind_Speed_kmh', 'Atmospheric_Pressure_hPa', 'Visibility_km']].corr())
# Out:
# <Axes: >

# %% [markdown]
# ## Observation

# %% [markdown]
# AQI is highly affected by temparature, humidity and rainfall, but it is seen that it does not get much affected from wind speed and atmospheric pressure.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Mumbai, a coastal city, experiences varied Air Quality throught the year due to various changes in concentration of pollutants due to seasonal and weather changes. Monsoon plays a major role in air quality for Mumbai. In comparison to Delhi, air quality is better.
